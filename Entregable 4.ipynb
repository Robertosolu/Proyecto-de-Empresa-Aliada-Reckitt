# %%
import sqlite3

# %%
conn = sqlite3.connect("Entregable_4")

# %%
cur = conn.cursor()

# %%
import os
import csv

os.chdir("/Users/Gregorio/Proyecto Empresa Aliada")
with open("DIM_CATEGORY.csv") as f:
    reader = csv.reader(f)
    data = list(reader)

# %%
data
# Out:
# [['ID_CATEGORY', 'CATEGORY'],
#  ['1', 'FABRIC TREATMENT and SANIT\n'],
#  ['2', 'AIR CARE '],
#  ['3', 'LAVAVAJILLAS'],
#  ['4', 'MEGA SUPERFICIES'],
#  ['5', 'LAVATORY CARE & BRC']]

# %%
# Creacion de la tabla donde se importara el archivo csv
cur.execute("""
    CREATE TABLE Categoria (
    Id_Category NUMERIC,
    Category TEXT);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Creacion de la tabla donde se importara el archivo csv
# ----> 2 cur.execute("""
#       3     CREATE TABLE Categoria (
#       4     Id_Category NUMERIC,
#       5     Category TEXT);
#       6 """)
#
# OperationalError: table Categoria already exists

# %%
# insersion de los datos en la tabla recien creada
for renglon in range(1, len(data)):
    cur.execute("""
        INSERT INTO Categoria (Id_Category, Category)
        VALUES (?,?)
    """, data[renglon])

# %%
# Aplicacion de los cambios
conn.commit()

# %%
cur.execute("SELECT * FROM Categoria;")

# %%
cur.execute("""SELECT Category FROM Categoria""")
result = cur.fetchall()
result

# %%
result = cur.fetchall()
result

# %%
os.chdir("/Users/Gregorio/Proyecto Empresa Aliada")
with open("FACT_SALES.csv") as f:
    reader = csv.reader(f)
    data = list(reader)

# %%
data

# %%
# Creacion de la tabla donde se importara el archivo csv
cur.execute("""
    CREATE TABLE Ventas (
    Week TEXT,
    Item_Code TEXT,
    Total_Unit_Sales NUMERIC,
    Total_Value_Sales NUMERIC,
    Total_Unit_Avg_Weekly_Sales NUMERIC,
    Region TEXT);
""")

# %%
# insersion de los datos en la tabla recien creada
for renglon in range(1, len(data)):
    cur.execute("""
        INSERT INTO Ventas (Week, Item_Code, Total_Unit_Sales, Total_Value_Sales, Total_Unit_Avg_Weekly_Sales, Region)
        VALUES (?,?,?,?,?,?)
    """, data[renglon])

# %%
# Aplicacion de los cambios
conn.commit()

# %%
cur.execute("SELECT * FROM Ventas;")

# %%
result = cur.fetchall()
result

# %%
cur.execute("""SELECT Total_Unit_Sales FROM Ventas DESC""")
result = cur.fetchall()
result

# %%
import openpyxl

Calendario = openpyxl.load_workbook("DIM_CALENDAR.xlsx")
sheet = wb.active  # Selecciona la primera hoja

data = []
for row in sheet.iter_rows(values_only=True):
    data.append(row)

# %%
data

# %%
# Creacion de la tabla donde se importara el archivo csv
cur.execute("""
    CREATE TABLE Calendario (
    Week, TEXT,
    Year TEXT,
    Month TEXT,
    Week_Number TEXT);
""")

# %%
# insersion de los datos en la tabla recien creada
for renglon in range(1, len(data)):
    cur.execute("""
        INSERT INTO Calendario (Week, Year, Month, Week_Number)
        VALUES (?,?,?,?)
    """, data[renglon][:4])

# %%
# Aplicacion de los cambios
conn.commit()

# %%
cur.execute("SELECT * FROM Calendario;")
result = cur.fetchall()
result

# %%
import openpyxl
Segmento = openpyxl.load_workbook("DIM_SEGMENT.xlsx")
sheet = wb.active
data = []  # Lista para almacenar los datos

for row in sheet.iter_rows(values_only=True):  # Extrae solo los valores
    data.append(row)

# %%
data

# %%
# Creacion de la tabla donde se importara el archivo csv
cur.execute("""
    CREATE TABLE Segmento (
    Category NUMERIC,
    ATTR1 TEXT,
    ATTR2 TEXT,
    ATTR3 TEXT,
    Format TEXT,
    Segment TEXT);
""")

# %%
# insersion de los datos en la tabla recien creada
for renglon in range(1, len(data)):
    cur.execute("""
        INSERT INTO Segmento (Category, ATTR1, ATTR2, ATTR3, Format, Segment)
        VALUES (?,?,?,?,?,?)
    """, data[renglon])

# %%
# Aplicacion de los cambios
conn.commit()

# %%
cur.execute("SELECT * FROM Segmento;")
result = cur.fetchall()
result

# %%
data

# %%
import openpyxl
Producto = openpyxl.load_workbook("DIM_PRODUCT.xlsx")
sheet = wb.active
data = []  # Lista para almacenar los datos

for row in sheet.iter_rows(values_only=True):  # Extrae solo los valores
    data.append(row)

print(data)  # Muestra los datos en formato de lista

# %%
# Creacion de la tabla donde se importara el archivo csv
cur.execute("""
    CREATE TABLE Producto (
    Manufacturer TEXT,
    Brand TEXT,
    Item TEXT,
    Item_Description TEXT,
    Category NUMERIC,
    Format TEXT,
    ATTR1 TEXT,
    ATTR2 TEXT,
    ATTR3 TEXT);
""")

# %%
# insersion de los datos en la tabla recien creada
for renglon in range(1, len(data)):
    cur.execute("""
        INSERT INTO Producto (Manufacturer, Brand, Item, Item_Description, Category, Format, ATTR1, ATTR2, ATTR3)
        VALUES (?,?,?,?,?,?,?,?,?)
    """, data[renglon])

# %%
# Aplicacion de los cambios
conn.commit()

# %%
cur.execute("SELECT * FROM Producto;")
result = cur.fetchall()
result

# %%
cur.execute("""SELECT 
    V.Total_UNit_sales,
    S.Segment
    FROM Ventas V, Segmento S
""")
result =cur.fetchall()
result
# Out:
# [(0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'BLEACH'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'POWDER'),
#  (0.006, 'OTHERS'),
#  (0.006, 'PRETREAT'),
#  (0.006, 'PRETREAT'),
#  (0.006, 'POWDER'),
#  (0.006, 'PRETREAT'),
#  (0.006, 'PRETREAT'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'PRETREAT'),
#  (0.006, 'POWDER'),
#  (0.006, 'BAR'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'POWDER'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'BAR'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'POWDER'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'BAR'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'PRETREAT'),
#  (0.006, 'POWDER'),
#  (0.006, 'LIQUID & GEL'),
#  (0.006, 'LIQUID & GEL'),
# ...

# %%
conn.close()

# %%
conn = sqlite3.connect("Entregable_4")

# %%
cur.execute("""SELECT v.Total_Unit_sales, p.Brand
            FROM Ventas AS v INNER JOIN Producto AS p
            ON v.Item_Code = p.Item""")
result = cur.fetchall()
result
# Out:
# [(0.006, 'VANISH'),
#  (0.487, 'VANISH'),
#  (1.391, 'VANISH'),
#  (0.022, 'VANISH'),
#  (2.037, 'VANISH'),
#  (0.005, 'VANISH'),
#  (0.004, 'VANISH'),
#  (0.001, 'VANISH'),
#  (0.716, 'VANISH'),
#  (2.704, 'VANISH'),
#  (2.188, 'VANISH'),
#  (0.811, 'VANISH'),
#  (3.507, 'VANISH'),
#  (6.539, 'VANISH'),
#  (2.547, 'VANISH'),
#  (6.774, 'VANISH'),
#  (0.008, 'VANISH'),
#  (0.997, 'VANISH'),
#  (0.078, 'VANISH'),
#  (0.351, 'VANISH'),
#  (0.004, 'VANISH'),
#  (1.428, 'VANISH'),
#  (2.532, 'VANISH'),
#  (0.024, 'SHOUT'),
#  (0.001, 'SHOUT'),
#  (0.184, 'LA VALENCIANA'),
#  (0.003, 'LA VALENCIANA'),
#  (0.041, 'LA VALENCIANA'),
#  (0.013, 'LOS PATITOS'),
#  (0.682, 'LOS PATITOS'),
#  (0.243, 'LOS PATITOS'),
#  (0.005, 'LOS PATITOS'),
#  (0.406, 'LOS PATITOS'),
#  (0.001, 'OXI CLEAN'),
#  (0.072, 'OXI CLEAN'),
#  (0.854, 'OXI CLEAN'),
#  (0.246, 'OXI CLEAN'),
#  (0.175, 'OXI CLEAN'),
#  (0.708, 'OXI CLEAN'),
#  (0.921, 'OXI CLEAN'),
#  (4.476, 'OXI CLEAN'),
#  (0.004, 'OXI CLEAN'),
# ...

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 conn.close()
#
# NameError: name 'conn' is not defined
